# %%
import pandas as pd
import os

# %%
info = os.path.abspath('../../output/PHANTOM1_3/info/dicominfo.txt')

# %%
pd.read_csv(info, sep='\t')
# Out:
#     total_files_till_now                                   example_dcm_file  \
# 0                    128  YAROSLAV.MR.HEAD_ADVANCED_APPLICATIONS_LIBRARI...
# 1                    133  YAROSLAV.MR.HEAD_ADVANCED_APPLICATIONS_LIBRARI...
# 2                    136  YAROSLAV.MR.HEAD_ADVANCED_APPLICATIONS_LIBRARI...
# 3                    139  YAROSLAV.MR.HEAD_ADVANCED_APPLICATIONS_LIBRARI...
# 4                    315  YAROSLAV.MR.HEAD_ADVANCED_APPLICATIONS_LIBRARI...
# 5                    337  YAROSLAV.MR.HEAD_ADVANCED_APPLICATIONS_LIBRARI...
# 6                    348  YAROSLAV.MR.HEAD_ADVANCED_APPLICATIONS_LIBRARI...
# 7                    373  YAROSLAV.MR.HEAD_ADVANCED_APPLICATIONS_LIBRARI...
# 8                    388  YAROSLAV.MR.HEAD_ADVANCED_APPLICATIONS_LIBRARI...
# 9                    403  YAROSLAV.MR.HEAD_ADVANCED_APPLICATIONS_LIBRARI...
# 10                   404  YAROSLAV.MR.HEAD_ADVANCED_APPLICATIONS_LIBRARI...
# ...
